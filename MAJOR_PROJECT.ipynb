# %%
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/covid_19_india.csv')
df.shape
# Out:
# (7086, 9)

# %%
df.isnull()
# Out:
#         Sno   Date   Time  ...  Cured  Deaths  Confirmed
# 0     False  False  False  ...  False   False      False
# 1     False  False  False  ...  False   False      False
# 2     False  False  False  ...  False   False      False
# 3     False  False  False  ...  False   False      False
# 4     False  False  False  ...  False   False      False
# ...     ...    ...    ...  ...    ...     ...        ...
# 7081  False  False  False  ...  False   False      False
# 7082  False  False  False  ...  False   False      False
# 7083  False  False  False  ...  False   False      False
# 7084  False  False  False  ...  False   False      False
# 7085  False  False  False  ...  False   False      False
#
# [7086 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Sno                         0
# Date                        0
# Time                        0
# State/UnionTerritory        0
# ConfirmedIndianNational     0
# ConfirmedForeignNational    0
# Cured                       0
# Deaths                      0
# Confirmed                   0
# dtype: int64

# %%
df.head()
# Out:
#    Sno      Date     Time  ... Cured Deaths Confirmed
# 0    1  30/01/20  6:00 PM  ...     0      0         1
# 1    2  31/01/20  6:00 PM  ...     0      0         1
# 2    3  01/02/20  6:00 PM  ...     0      0         2
# 3    4  02/02/20  6:00 PM  ...     0      0         3
# 4    5  03/02/20  6:00 PM  ...     0      0         3
#
# [5 rows x 9 columns]

# %%
df.tail()
# Out:
#        Sno      Date     Time  ...   Cured Deaths Confirmed
# 7081  7082  07/10/20  8:00 AM  ...  177008   1189    204748
# 7082  7083  07/10/20  8:00 AM  ...   22623    301     27545
# 7083  7084  07/10/20  8:00 AM  ...   43238    677     52329
# 7084  7085  07/10/20  8:00 AM  ...  370753   6153    420937
# 7085  7086  07/10/20  8:00 AM  ...  243743   5318    277049
#
# [5 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7086 entries, 0 to 7085
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       7086 non-null   int64
#  1   Date                      7086 non-null   object
#  2   Time                      7086 non-null   object
#  3   State/UnionTerritory      7086 non-null   object
#  4   ConfirmedIndianNational   7086 non-null   object
#  5   ConfirmedForeignNational  7086 non-null   object
#  6   Cured                     7086 non-null   int64
#  7   Deaths                    7086 non-null   int64
#  8   Confirmed                 7086 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 498.4+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7086 entries, 0 to 7085
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       7086 non-null   int64
#  1   Date                      7086 non-null   datetime64[ns]
#  2   Time                      7086 non-null   object
#  3   State/UnionTerritory      7086 non-null   object
#  4   ConfirmedIndianNational   7086 non-null   object
#  5   ConfirmedForeignNational  7086 non-null   object
#  6   Cured                     7086 non-null   int64
#  7   Deaths                    7086 non-null   int64
#  8   Confirmed                 7086 non-null   int64
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 498.4+ KB

# %%
df.index = pd.PeriodIndex(df.Date,freq='M')

# %%
df.index
# Out:
# PeriodIndex(['2020-01', '2020-01', '2020-01', '2020-02', '2020-03', '2020-04',
#              '2020-05', '2020-06', '2020-07', '2020-08',
#              ...
#              '2020-07', '2020-07', '2020-07', '2020-07', '2020-07', '2020-07',
#              '2020-07', '2020-07', '2020-07', '2020-07'],
#             dtype='period[M]', name='Date', length=7086, freq='M')

# %%
df.head()
# Out:
#          Sno       Date     Time  ... Cured Deaths Confirmed
# Date                              ...
# 2020-01    1 2020-01-30  6:00 PM  ...     0      0         1
# 2020-01    2 2020-01-31  6:00 PM  ...     0      0         1
# 2020-01    3 2020-01-02  6:00 PM  ...     0      0         2
# 2020-02    4 2020-02-02  6:00 PM  ...     0      0         3
# 2020-03    5 2020-03-02  6:00 PM  ...     0      0         3
#
# [5 rows x 9 columns]

# %%
df.index.rename('DateNew',inplace = True)

# %%
df.index
# Out:
# PeriodIndex(['2020-01', '2020-01', '2020-01', '2020-02', '2020-03', '2020-04',
#              '2020-05', '2020-06', '2020-07', '2020-08',
#              ...
#              '2020-07', '2020-07', '2020-07', '2020-07', '2020-07', '2020-07',
#              '2020-07', '2020-07', '2020-07', '2020-07'],
#             dtype='period[M]', name='DateNew', length=7086, freq='M')

# %%
df.describe()
# Out:
#                Sno         Cured        Deaths     Confirmed
# count  7086.000000  7.086000e+03   7086.000000  7.086000e+03
# mean   3543.500000  3.423502e+04    836.188682  4.534495e+04
# std    2045.696336  9.913313e+04   2997.188810  1.263801e+05
# min       1.000000  0.000000e+00      0.000000  0.000000e+00
# 25%    1772.250000  3.800000e+01      1.000000  1.660000e+02
# 50%    3543.500000  1.499500e+03     22.000000  2.774000e+03
# 75%    5314.750000  1.664325e+04    396.000000  2.573375e+04
# max    7086.000000  1.179726e+06  38717.000000  1.465911e+06

# %%
df = df.sort_values(by='Date')

# %%
df.head(5)
# Out:
#          Sno       Date     Time  ... Cured Deaths Confirmed
# DateNew                           ...
# 2020-01    3 2020-01-02  6:00 PM  ...     0      0         2
# 2020-01   32 2020-01-03  6:00 PM  ...     0      0         3
# 2020-01  530 2020-01-04  7:30 PM  ...     1      0        83
# 2020-01  531 2020-01-04  7:30 PM  ...     0      0        10
# 2020-01  532 2020-01-04  7:30 PM  ...     0      0         1
#
# [5 rows x 9 columns]

# %%
df.tail()
# Out:
#           Sno       Date     Time  ...   Cured Deaths Confirmed
# DateNew                            ...
# 2020-12  6189 2020-12-09  8:00 AM  ...    5839     71      8784
# 2020-12  6190 2020-12-09  8:00 AM  ...   34689    854     50712
# 2020-12  6191 2020-12-09  8:00 AM  ...   43328    532     59040
# 2020-12  6185 2020-12-09  8:00 AM  ...  178154   4687    209748
# 2020-12  6211 2020-12-09  8:00 AM  ...  169043   3828    196332
#
# [5 rows x 9 columns]

# %%
df.Confirmed.plot(figsize=(14,5))

# %%
df.plot(kind='line',y=['Confirmed','Cured'],figsize=(14,5))

# %%
df['active_cases'] = df['Confirmed']-df['Cured']

# %%
df.plot(kind='line',y=['active_cases'])

# %%
df['monthval'] = pd.DatetimeIndex(df['Date']).month
df.head()
# Out:
#          Sno       Date     Time  ... Confirmed active_cases monthval
# DateNew                           ...
# 2020-01    3 2020-01-02  6:00 PM  ...         2            2        1
# 2020-01   32 2020-01-03  6:00 PM  ...         3            3        1
# 2020-01  530 2020-01-04  7:30 PM  ...        83           82        1
# 2020-01  531 2020-01-04  7:30 PM  ...        10           10        1
# 2020-01  532 2020-01-04  7:30 PM  ...         1            1        1
#
# [5 rows x 11 columns]

# %%
dfPivot = pd.pivot_table(df,values = 'active_cases',columns='State/UnionTerritory',index='monthval')

# %%
dfPivot
# Out:
# State/UnionTerritory  Andaman and Nicobar Islands  ...   West Bengal
# monthval                                           ...
# 1                                      160.000000  ...  13153.142857
# 2                                      165.428571  ...  13249.285714
# 3                                       97.461538  ...   4476.809524
# 4                                       57.040000  ...   4049.360000
# 5                                       51.692308  ...   5262.846154
# 6                                       66.560000  ...   8089.400000
# 7                                      126.461538  ...  16849.923077
# 8                                      746.480000  ...  25335.640000
# 9                                      232.125000  ...  24774.291667
# 10                                     211.500000  ...  11911.500000
# 11                                     222.666667  ...  12036.833333
# 12                                     238.000000  ...  12206.166667
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(df['active_cases'])
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
dfPivot.plot(figsize=(14,5))

# %%
df_new = df[['Date','active_cases']]
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 7086 entries, 2020-01 to 2020-12
# Freq: M
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          7086 non-null   datetime64[ns]
#  1   active_cases  7086 non-null   int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 166.1 KB

# %%
df_new = df_new.rename(columns={'Date':'ds','active_cases':'y'})
df_new
# Out:
#                 ds      y
# DateNew
# 2020-01 2020-01-02      2
# 2020-01 2020-01-03      3
# 2020-01 2020-01-04     82
# 2020-01 2020-01-04     10
# 2020-01 2020-01-04      1
# ...            ...    ...
# 2020-12 2020-12-09   2945
# 2020-12 2020-12-09  16023
# 2020-12 2020-12-09  15712
# 2020-12 2020-12-09  31594
# 2020-12 2020-12-09  27289
#
# [7086 rows x 2 columns]

# %%
import pandas as pd
from fbprophet import Prophet

# %%
m = Prophet()
m.fit(df_new)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#             ds
# 612 2021-12-05
# 613 2021-12-06
# 614 2021-12-07
# 615 2021-12-08
# 616 2021-12-09

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds          yhat     yhat_lower    yhat_upper
# 612 2021-12-05 -36613.156730  -95866.576441  30761.791739
# 613 2021-12-06 -36670.884829  -99642.180996  25680.987779
# 614 2021-12-07 -37200.625287 -102057.858247  27238.369367
# 615 2021-12-08 -36466.183216 -100005.454945  28709.576623
# 616 2021-12-09 -37582.810288 -101520.995961  23733.360601

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
from fbprophet.plot import plot_plotly, plot_components_plotly

plot_plotly(m, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e64ff96e-97aa-45cd-acaf-8108ec80ca66" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e64ff96e-97aa-45cd-acaf-8108ec80ca66")) {
#                     Plotly.newPlot(
#                         'e64ff96e-97aa-45cd-acaf-8108ec80ca66',
# ...

# %%
plot_components_plotly(m, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3f205254-96bb-426f-b904-fd12f8ef2e6e" class="plotly-graph-div" style="height:400px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3f205254-96bb-426f-b904-fd12f8ef2e6e")) {
#                     Plotly.newPlot(
#                         '3f205254-96bb-426f-b904-fd12f8ef2e6e',
# ...

# %% [markdown]
# **highest active cases in which state.?**

# %%
max=df['active_cases'].max()
max_df=df[['State/UnionTerritory','active_cases']][df['active_cases']>max-1]
max_df
# Out:
#         State/UnionTerritory  active_cases
# DateNew
# 2020-09          Maharashtra        333486

# %% [markdown]
# **Highest Cured State.?** bold text

# %%
max=df['Cured'].max()
max_df=df[['State/UnionTerritory','Cured']][df['Cured']>max-1]
max_df
# Out:
#         State/UnionTerritory    Cured
# DateNew
# 2020-07          Maharashtra  1179726

# %% [markdown]
# **Highest Death State.?**

# %%
max=df['Deaths'].max()
max_df=df[['State/UnionTerritory','Deaths']][df['Deaths']>max-1]
max_df
# Out:
#         State/UnionTerritory  Deaths
# DateNew
# 2020-07          Maharashtra   38717

# %% [markdown]
# **Least Affected State.?**

# %%
min=df['Confirmed'].min()
min_df=df[['State/UnionTerritory','Confirmed']][df['Confirmed']<min+1]
min_df
# Out:
#         State/UnionTerritory  Confirmed
# DateNew
# 2020-04             Nagaland          0
# 2020-04             Nagaland          0
# 2020-04             Nagaland          0
# 2020-04             Nagaland          0
# 2020-04             Nagaland          0
# 2020-04             Nagaland          0
# 2020-04             Nagaland          0

# %%
df = df.replace(['-'],'0')

# %%
df.iloc[:,4:6] = df.iloc[:,4:5].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 7086 entries, 2020-01 to 2020-12
# Freq: M
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       7086 non-null   int64
#  1   Date                      7086 non-null   datetime64[ns]
#  2   Time                      7086 non-null   object
#  3   State/UnionTerritory      7086 non-null   object
#  4   ConfirmedIndianNational   7086 non-null   int64
#  5   ConfirmedForeignNational  0 non-null      float64
#  6   Cured                     7086 non-null   int64
#  7   Deaths                    7086 non-null   int64
#  8   Confirmed                 7086 non-null   int64
#  9   active_cases              7086 non-null   int64
#  10  monthval                  7086 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(7), object(2)
# memory usage: 664.3+ KB

# %% [markdown]
# **Highest National confirmed Cases.?**

# %%
max=df['ConfirmedIndianNational'].max()
max_df=df[['State/UnionTerritory','ConfirmedIndianNational']][df['ConfirmedIndianNational']>max-1]
max_df
# Out:
#         State/UnionTerritory  ConfirmedIndianNational
# DateNew
# 2020-03          Maharashtra                      177

# %% [markdown]
# **which Date has highest Confirmed Cases.?**

# %%
max=df['Confirmed'].max()
max_df=df[['Date','Confirmed']][df['Confirmed']>max-1]
max_df
# Out:
#               Date  Confirmed
# DateNew
# 2020-07 2020-07-10    1465911

# %% [markdown]
# **which Date has Lowest Confirmed Cases.?**

# %%
min=df['Confirmed'].min()
min_df=df[['Date','Confirmed']][df['Confirmed']<min+1]
min_df
# Out:
#               Date  Confirmed
# DateNew
# 2020-04 2020-04-15          0
# 2020-04 2020-04-16          0
# 2020-04 2020-04-17          0
# 2020-04 2020-04-18          0
# 2020-04 2020-04-19          0
# 2020-04 2020-04-20          0
# 2020-04 2020-04-21          0

# %% [markdown]
# **Lowest Active Cases Recorded on.?**

# %%
min=df['active_cases'].min()
min_df=df[['State/UnionTerritory','active_cases']][df['active_cases']<min+1]
min_df
# Out:
#                 State/UnionTerritory  active_cases
# DateNew
# 2020-01                          Goa             0
# 2020-01                      Manipur             0
# 2020-01                      Tripura             0
# 2020-01            Arunachal Pradesh             0
# 2020-01                      Mizoram             0
# ...                              ...           ...
# 2020-12  Andaman and Nicobar Islands             0
# 2020-12            Arunachal Pradesh             0
# 2020-12                          Goa             0
# 2020-12                      Mizoram             0
# 2020-12                      Manipur             0
#
# [163 rows x 2 columns]
